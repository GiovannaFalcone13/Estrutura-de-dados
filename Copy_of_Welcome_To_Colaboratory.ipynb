# %% [markdown]
# <a href="https://colab.research.google.com/github/GiovannaFalcone13/Estrutura-de-dados/blob/main/Copy_of_Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # Função
## Autora: Giovanna Falcoe Vasconcellos Marques
#Data:16/06/2023
##Observações:
#
  class Livro:
    def __init__ (self,autor,titulo,editora,ano):
      self_autor=autor
      self_titulo=titulo
      self_editora=editora
      self_ano=ano
      self_proximo=None

 class Biblioteca:
  def __init__ (self):
    self_head= None

  def inserir_ordenado(self,autor,titulo,editora,ano):
    novo_novo = Livro(autor,titulo,editora,ano)
    if self_head is None:
            self_head = novo_livro
        else:
            # Se o novo livro deve ser o primeiro da lista
            if novo_livro.titulo < self.head.titulo:
                novo_livro.proximo = self.head
                self_head = novo_livro
            else:
                atual = self.head

                while atual.proximo is not None and novo_livro.titulo > atual.proximo.titulo:
                    atual = atual.proximo

                novo_livro.proximo = atual.proximo
                atual.proximo = novo_livro
     def remover(self, titulo):
        atual = self.head
        anterior = None

        while atual is not None:
            if atual.titulo == titulo:
                if anterior is None:
                    self.head = atual.proximo
                else:
                    anterior.proximo = atual.proximo

                return

            anterior = atual
            atual = atual.proximo
            print("Livro não encontrado!")

     def alterar(self, titulo, novo_autor, nova_editora, novo_ano):
        atual = self.head

        while atual is not None:
            if atual.titulo == titulo:
                atual.autor = novo_autor
                atual.editora = nova_editora
                atual.ano = novo_ano
                return

            atual = atual.proximo

        print("Livro não encontrado!")
    def buscar_por_titulo(self, titulo):
        atual = self.head

        while atual is not None:
            if atual.titulo == titulo:
                return atual

            atual = atual.proximo

        return None

    def buscar_por_autor(self, autor):
        atual = self.head
        livros_autor = []

        while atual is not None:
            if atual.autor == autor:
                livros_autor.append(atual)

            atual = atual.proximo

        return livros_autor

    def mostrar_livros(self):
        atual = self.head

        if atual is None:
            print("Biblioteca vazia!")
        else:
            while atual is not None:
                print("Autor:", atual.autor)
                print("Título:", atual.titulo)
                print("Editora:", atual.editora)
                print("Ano de edição:", atual.ano)
                print()
                atual = atual.proximo

def exibir_menu():
    print("==== MENU ====")
    print("1. Inserir livro")
    print("2. Remover livro")
    print("3. Alterar livro")
    print("4. Buscar por título")
    print("5. Buscar por autor")
    print("6. Mostrar todos os livros")
    print("0. Sair")
    print()

biblioteca = Biblioteca()

biblioteca =

 while True:
    exibir_menu()
    opcao =

input("Digite a opção desejada: ")

    if opcao == "1":
        autor = input("Digite o autor do livro: ")
        titulo =

input("Digite o título do livro: ")
        editora =
        editora =
input("Digite a editora do livro: ")
        ano =

input("Digite o ano de edição do livro: ")

        biblioteca.inserir_ordenado(autor, titulo, editora, ano)


        biblioteca.inserir_ordenado(autor, titulo, editora, ano)

        biblioteca.inserir_ordenado

        biblioteca.inserir_orden
    print("Livro inserido com sucesso!")

    elif opcao == "2":
        titulo =

  input("Digite o título do livro que deseja remover: ")
        biblioteca.remover(titulo)

    elif opcao == "3":
        titulo =

    input("Digite o título do livro que deseja alterar: ")
        novo_autor =

    input("Digite o novo autor: ")
        nova_editora = input("Digite a nova editora: ")
        novo_ano =

    input("Digite o novo ano de edição: ")

        biblioteca.alterar(titulo, novo_autor, nova_editora, novo_ano)

        biblioteca.alterar(titulo, novo_autor, nova_editora, novo_ano)

        biblioteca.alterar(titulo, novo_autor

    print("Livro alterado com sucesso!")


      elif opcao == "4":
        titulo =
        titulo
    input("Digite o título do livro que deseja buscar: ")
        livro = biblioteca.buscar_por_titulo(titulo)

        livro = biblioteca.buscar_por_titulo(titulo)

        livro = biblioteca.buscar_por_titulo(titulo)

        if livro is not None:
            print("Livro encontrado:")
            print("Autor:", livro.autor)
            print("Título:", livro.titulo)
            print("Editora:", livro.editora)
            print("Ano de edição:", livro.ano)
        else:
            print("Livro não encontrado!")

        elif opcao == "5":
        autor = input("Digite o nome do autor: ")
        livros_autor = biblioteca.buscar_por_autor(autor)

        livros_autor = biblioteca.buscar_por_autor(autor)

        livros_autor = biblioteca

    if len(livros_autor) > 0:
            print("Livros do autor", autor + ":")
            for livro in livros_autor:


    print("Título:", livro.titulo)
        else:
            print("Nenhum livro encontrado para o autor", autor)

     elif opcao == "6":
        biblioteca.mostrar_livros()

     elif opcao == "0":
        break

     else:
        print("Opção inválida!")
      print()
# Out:
#   File "<tokenize>", line 22
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
#Prova4 Qustão3
#Lista
Artistas=[]
QuantArtistas=300

#Entradas
Nome=str.lower(input("Digite seu nome"))
TipoArtista=str.lower(input("Que tipo de artista você é(banda ou cator ou cantora"))
CachêCobradoi=int(input("Quanto você cobra?"))
CidadeOrigem=str.lower(input)("Qual sua cidade de origem?")

#Adicionar dados a lista Artistas
DadosArtistas=[Nome, TipoArtista, CachêCobrado, CidadeOrigem]
Artistas.append(DadosArtistas)

#Lista bandas das cidades Mamanguape, Rio Tinto e Mataraca que cobram menos de 5000
for i in range(len(Artistas)):
  if(Artistas[i][1].lower()==("banda")and(Artistas[i][2]<5000)and(Artistas[i][3]())==("Mamanguape" or "Rio Tinto" or "Mataraca")
    print(Artistas[i][0])

#Cachê médio cobrado pelas cantoras
CachêMédio=0
QuantCantoras=0
for i in range(len(Artistas)):
  if("Cantoras" in Artistas[i][1].lower()):
   CachêMédio+=Artistas[i][2]
   QuantCantoras+=1
   MédiaCachê=CachêMédio//Quantcantoras
   print("A média do cachê é", MédiaCachê)

 # Cidades que tem cantores cobrando mais de 10000 por show
for i in range(len(Artistas)):
  if(Artistas[i][1].lower()==("cantor"or "cantora")and(Artistas[i][2]>10000)
  print(Artistas[i][3])
